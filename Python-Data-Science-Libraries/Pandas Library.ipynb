# %% [markdown]
# ## PANDAS library

# %% [markdown]
# PANDAS series
# it is one dimension laled array capable holding any data type showing with index

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %% [markdown]
# DATA Frames

# %%
data={
    'name':['numan','sanan','arsalan','zayan'],
    'age':[34,56,56,67],
    'city':['swabi','adina','queta','hushal'],
    'salary':['2000',30000,40000,78000]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#       name  age    city salary
# 0    numan   34   swabi   2000
# 1    sanan   56   adina  30000
# 2  arsalan   56   queta  40000
# 3    zayan   67  hushal  78000

# %%
# for list how to create datafram 
data_list=[
    ['numan','sanan','arsalan','zayan'],
    [34,56,56,67],
    ['swabi','adina','queta','hushal'],
    ['2000',30000,40000,78000]
]

# %%
df2=pd.DataFrame(data_list)
df2
# Out:
#        0      1        2       3
# 0  numan  sanan  arsalan   zayan
# 1     34     56       56      67
# 2  swabi  adina    queta  hushal
# 3   2000  30000    40000   78000

# %%
# now to add column odf name age city salary
colum=["name","age","city","salary"]
df2=pd.DataFrame(data_list,columns=colum)
df2
# Out:
#     name    age     city  salary
# 0  numan  sanan  arsalan   zayan
# 1     34     56       56      67
# 2  swabi  adina    queta  hushal
# 3   2000  30000    40000   78000

# %% [markdown]
# Selection and indexing of columns

# %%
df2['name']
# Out:
# 0    numan
# 1       34
# 2    swabi
# 3     2000
# Name: name, dtype: object

# %%
df2['age']
# Out:
# 0    sanan
# 1       56
# 2    adina
# 3    30000
# Name: age, dtype: object

# %%
df2[['name','city']]
# Out:
#     name     city
# 0  numan  arsalan
# 1     34       56
# 2  swabi    queta
# 3   2000    40000

# %% [markdown]
# Create new colmn

# %%
df2["role"]=['dr','eng','dr','eng']
df2
# Out:
#     name    age     city  salary role
# 0  numan  sanan  arsalan   zayan   dr
# 1     34     56       56      67  eng
# 2  swabi  adina    queta  hushal   dr
# 3   2000  30000    40000   78000  eng

# %% [markdown]
# removin column

# %%
df2.drop('role',axis=1)
# Out:
#     name    age     city  salary
# 0  numan  sanan  arsalan   zayan
# 1     34     56       56      67
# 2  swabi  adina    queta  hushal
# 3   2000  30000    40000   78000

# %%
df2
# Out:
#     name    age     city  salary role
# 0  numan  sanan  arsalan   zayan   dr
# 1     34     56       56      67  eng
# 2  swabi  adina    queta  hushal   dr
# 3   2000  30000    40000   78000  eng

# %%
df2.drop('role',axis=1,inplace=True)

# %%
df2
# Out:
#     name    age     city  salary
# 0  numan  sanan  arsalan   zayan
# 1     34     56       56      67
# 2  swabi  adina    queta  hushal
# 3   2000  30000    40000   78000

# %%
# for removing 2 columns at same Time
df2.drop(['age','city'],axis=1)
# Out:
#     name  salary
# 0  numan   zayan
# 1     34      67
# 2  swabi  hushal
# 3   2000   78000

# %%
df2
# Out:
#     name    age     city  salary
# 0  numan  sanan  arsalan   zayan
# 1     34     56       56      67
# 2  swabi  adina    queta  hushal
# 3   2000  30000    40000   78000

# %%
# for row same use but axis =0 for row
df2.drop(0,axis=0)
# Out:
#     name    age   city  salary
# 1     34     56     56      67
# 2  swabi  adina  queta  hushal
# 3   2000  30000  40000   78000

# %%
df2
# Out:
#     name    age     city  salary
# 0  numan  sanan  arsalan   zayan
# 1     34     56       56      67
# 2  swabi  adina    queta  hushal
# 3   2000  30000    40000   78000

# %%
# for row selection print

df.loc[0]
# Out:
# name      numan
# age          34
# city      swabi
# salary     2000
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#     name  age   city salary
# 0  numan   34  swabi   2000
# 1  sanan   56  adina  30000

# %%
df.iloc[3]  #index location
# Out:
# name       zayan
# age           67
# city      hushal
# salary     78000
# Name: 3, dtype: object

# %%
# slect subset of rows and colmns
df.loc[[0,1]]
# Out:
#     name  age   city salary
# 0  numan   34  swabi   2000
# 1  sanan   56  adina  30000

# %%
df.loc[[0,1]][["city","salary"]]
# Out:
#     city salary
# 0  swabi   2000
# 1  adina  30000

# %%
df.loc[[2,3]][["name","age"]]
# Out:
#       name  age
# 2  arsalan   56
# 3    zayan   67

# %% [markdown]
# condition statement

# %%
# only want to see those people whos age is above 30

df[df["age"]>30]
# Out:
#       name  age    city salary
# 0    numan   34   swabi   2000
# 1    sanan   56   adina  30000
# 2  arsalan   56   queta  40000
# 3    zayan   67  hushal  78000

# %%
df[(df["age"]>30) & (df["city"]=='queta')]
# Out:
#       name  age   city salary
# 2  arsalan   56  queta  40000

# %% [markdown]
# Missing DATA

# %%
data={
    'A':[1,2,np.nan,4,5],
    'B':[1,2,3,4,5],
    'C':[1,2,3,np.nan,np.nan],
    'D':[1,np.nan,np.nan,np.nan,5]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
df.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df.dropna(thresh=3)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(0)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  0.0
# 2  0.0  3  3.0  0.0
# 3  4.0  4  0.0  0.0
# 4  5.0  5  0.0  5.0

# %%
values={'A':0,'B':100,'C':300,'D':400}
df.fillna(value=values)
# Out:
#      A  B      C      D
# 0  1.0  1    1.0    1.0
# 1  2.0  2    2.0  400.0
# 2  0.0  3    3.0  400.0
# 3  4.0  4  300.0  400.0
# 4  5.0  5  300.0    5.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(df.mean())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0

# %% [markdown]
# mergin joinng concatination

# %%
# DataFrame 1: Employees
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salaries
salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
employees
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR

# %%
salaries
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
pd.merge(employees,salaries,on='employee_id',how='inner')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(employees,salaries,on='employee_id',how='outer')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
pd.merge(employees,salaries,on='employee_id',how='left')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
pd.merge(employees,salaries,on='employee_id',how='right')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %% [markdown]
# concatination

# %%
# DataFrame 1
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2']
})

# DataFrame 2
df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5'],
    'C': ['C3', 'C4', 'C5']
})

# %%
df1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1,df2])
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %% [markdown]
# joining
# 2 data frames join

# %%
# DataFrame 1
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])

# DataFrame 2
df2 = pd.DataFrame({
    'score': [85, 90, 75]
}, index=[2, 3, 4])

# %%
df1
# Out:
#       name
# 1    Alice
# 2      Bob
# 3  Charlie

# %%
df2
# Out:
#    score
# 2     85
# 3     90
# 4     75

# %%
df1.join(df2,how='inner')
# Out:
#       name  score
# 2      Bob     85
# 3  Charlie     90

# %%
df1.join(df2,how='outer')
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0
# 4      NaN   75.0

# %% [markdown]
# groupby agrregation

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}

# %%
df=pd.DataFrame(data)
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
cat=df.groupby('Category')
cat

for i,v in cat:
    print(i)
    print(v)
# Out:
# A
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07
# B
#   Category Store  Sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    180        20 2023-01-06
# 7        B    S1    300        25 2023-01-08

# %%
# group by category and calculate the sum of sales

cat=df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
# group by Store and calculate the sum of sales

cat=df.groupby('Store')['Sales'].sum()
cat
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
# groupby multip colum
# group by catgeory and store
cat=df.groupby(['Category','Store'])['Sales'].sum()
cat
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %% [markdown]
# Aggregation
# agr kci chez ka hm combine rsult niklana chata wo aggregattion hta like mean etc

# %%
df['Sales'].mean()
# **********mean,mediam,min,max, count ,std*************
# Out:
# np.float64(187.5)

# %%
# agar hm zyafa operation lagana chaty hy tu
df['Sales'].agg(['mean','min','max'])
# Out:
# mean    187.5
# min     100.0
# max     300.0
# Name: Sales, dtype: float64

# %% [markdown]
# pivot tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

# %%
df=pd.DataFrame(data)
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    955     80   John
# 1  2023-01-02       B   West    492     76   Mary
# 2  2023-01-03       C  North    694     28    Bob
# 3  2023-01-04       D  South    381     51  Alice
# 4  2023-01-05       A   East    458     20   John
# 5  2023-01-06       B   West    395     53   Mary
# 6  2023-01-07       C  North    763     39    Bob
# 7  2023-01-08       D  South    484     17  Alice
# 8  2023-01-09       A   East    402     83   John
# 9  2023-01-10       B   West    458     26   Mary
# 10 2023-01-11       C  North    949     81    Bob
# 11 2023-01-12       D  South    876     53  Alice
# 12 2023-01-13       A   East    868     53   John
# 13 2023-01-14       B   West    791     34   Mary
# 14 2023-01-15       C  North    539     70    Bob
# 15 2023-01-16       D  South    232     12  Alice
# 16 2023-01-17       A   East    666     78   John
# 17 2023-01-18       B   West    299     74   Mary
# ...

# %%
# if u want ur values ur index ur columns then use pivot table

pd.pivot_table(df,values="Sales",index="Region",columns="Product",aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     666.0    NaN    NaN    NaN
# North      NaN    NaN  694.0    NaN
# South      NaN    NaN    NaN  484.0
# West       NaN  458.0    NaN    NaN

# %%
pivot2=pd.pivot_table(df,values=['Sales','Units'],index="Region",columns="Product",aggfunc='median')

# %%
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     666.0    NaN    NaN    NaN  78.0   NaN   NaN   NaN
# North      NaN    NaN  694.0    NaN   NaN   NaN  39.0   NaN
# South      NaN    NaN    NaN  484.0   NaN   NaN   NaN  17.0
# West       NaN  458.0    NaN    NaN   NaN  53.0   NaN   NaN

# %% [markdown]
# cross tabs
#
# it is used for counting prupose

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %% [markdown]
# DataFrames Basic Operations

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})

# %%
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     20 non-null     datetime64[ns]
#  1   Product  20 non-null     object
#  2   Region   20 non-null     object
#  3   Sales    20 non-null     int32
#  4   Units    20 non-null     int32
#  5   Rep      20 non-null     object
# dtypes: datetime64[ns](1), int32(2), object(3)
# memory usage: 932.0+ bytes

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %%
df1['A']+10
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# Name: A, dtype: int64

# %% [markdown]
# datraframe applying function

# %%
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
def square(x):
    return x**2

# %%
df1['B']=df1["B"].apply(square)

# or lamda ke throgh be kerskty same kaam 
df1['B']=df1["B"].apply(lambda x:x**2)

# %%
df1
# Out:
#    A        B    C
# 0  1    10000  100
# 1  2   160000  200
# 2  3   810000  300
# 3  4  2560000  400
# 4  5  6250000  500

# %%
# new colum b ban jaega or operation b apply hojaega 
df1['D']=df1["B"].apply(square)
df1
# Out:
#    A        B    C               D
# 0  1    10000  100       100000000
# 1  2   160000  200     25600000000
# 2  3   810000  300    656100000000
# 3  4  2560000  400   6553600000000
# 4  5  6250000  500  39062500000000

# %% [markdown]
# ## projects

# %% [markdown]
# Feature extraction project

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('anime.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    50 non-null     int64
#  1   Title   50 non-null     object
#  2   Score   50 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %%
df.head()
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
df.loc[1]
# Out:
# Rank                                                     2
# Title    Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...
# Score                                                 9.07
# Name: 1, dtype: object

# %%
df.loc[2]['Title']
# Out:
# 'Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members'

# %%
def extract_episode(txt):
    check=False
    data=""
    for i in txt:
        if i==")":
            check=False
            return data
        if check==True:
            data+=i
        if i=='(':
            check=True
    return data

# %%
df["Episodes"]=df["Title"].apply(extract_episode)
df["Episodes"]
# Out:
# 0      64 eps
# 1      24 eps
# 2      13 eps
# 3      51 eps
# 4      10 eps
# 5      51 eps
# 6       1 eps
# 7     148 eps
# 8      13 eps
# 9      13 eps
# 10      2 eps
# 11    110 eps
# 12     13 eps
# 13     13 eps
# 14     12 eps
# 15    201 eps
# 16      1 eps
# 17     22 eps
# 18     24 eps
# 19     25 eps
# 20      1 eps
# 21      1 eps
# 22      7 eps
# 23     14 eps
# 24     74 eps
# 25      1 eps
# 26      1 eps
# 27     12 eps
# 28      1 eps
# 29     24 eps
# 30     23 eps
# 31     12 eps
# 32     26 eps
# 33     13 eps
# 34     16 eps
# 35     11 eps
# 36      1 eps
# 37     11 eps
# 38     10 eps
# 39      1 eps
# 40     26 eps
# 41     12 eps
# 42     75 eps
# 43     26 eps
# 44     26 eps
# 45     24 eps
# 46     10 eps
# 47     12 eps
# 48     12 eps
# 49      4 eps
# Name: Episodes, dtype: object

# %%
df["Episodes"]=df["Episodes"].str.replace("eps","")

# %%
df
# Out:
#     Rank                                              Title  Score Episodes
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10      64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07      24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06      13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06      51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05      10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04      51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04       1
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04     148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04      13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03      13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03       2
# ...

# %%
df.loc[0]["Episodes"]
# Out:
# '64 '

# %%
df['Episodes']=df['Episodes'].astype(int)

# %%
df['Episodes']
# Out:
# 0      64
# 1      24
# 2      13
# 3      51
# 4      10
# 5      51
# 6       1
# 7     148
# 8      13
# 9      13
# 10      2
# 11    110
# 12     13
# 13     13
# 14     12
# 15    201
# 16      1
# 17     22
# 18     24
# 19     25
# 20      1
# 21      1
# 22      7
# 23     14
# 24     74
# 25      1
# 26      1
# 27     12
# 28      1
# 29     24
# 30     23
# 31     12
# 32     26
# 33     13
# 34     16
# 35     11
# 36      1
# 37     11
# 38     10
# 39      1
# 40     26
# 41     12
# 42     75
# 43     26
# 44     26
# 45     24
# 46     10
# 47     12
# 48     12
# 49      4
# Name: Episodes, dtype: int64

# %%
df.loc[0]['Episodes']
# Out:
# np.int64(64)

# %%
df.loc[2]['Title']
# Out:
# 'Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 - Dec 2022474,138 members'

# %%
def extraction_time(txt):
    check=False
    data=""
    for i in range (len(txt)):
        if txt[i]==')':
            for j in range(i+1,i+20):
                data+=txt[j]
            return data

# %%
df['Title'].apply(extraction_time)
# Out:
# 0     Apr 2009 - Jul 2010
# 1     Apr 2011 - Sep 2011
# 2     Oct 2022 - Dec 2022
# 3     Apr 2015 - Mar 2016
# 4     Apr 2019 - Jul 2019
# 5     Apr 2011 - Mar 2012
# 6     Jan 2021 - Jan 2021
# 7     Oct 2011 - Sep 2014
# 8     Apr 2022 - Jun 2022
# 9     Oct 2012 - Mar 2013
# 10    Mar 2023 - May 2023
# 11    Jan 1988 - Mar 1997
# 12    Jul 2023 - Aug 2023
# 13    Apr 2021 - Jun 2021
# 14    Jan 2017 - Mar 2017
# 15    Apr 2006 - Mar 2010
# 16    Sep 2016 - Sep 2016
# 17    Oct 2017 - Mar 2018
# 18    Oct 2008 - Mar 2009
# 19    Apr 2008 - Sep 2008
# 20    Jul 2013 - Jul 2013
# 21    Sep 2020 - Sep 2020
# 22    Aug 2017 - Aug 2017
# 23    Jul 2018 - Oct 2018
# 24    Apr 2004 - Sep 2005
# 25    Aug 2016 - Aug 2016
# 26    Dec 2022 - Dec 2022
# 27    Oct 2022 - Dec 2022
# 28    Dec 2022 - Dec 2022
# 29    Jan 2023 - Jun 2023
# 30    Jul 2023 - Aug 2023
# 31    Jan 2018 - Mar 2018
# 32    Apr 2020 - Oct 2021
# 33    Jan 2019 - Apr 2019
# 34    Dec 2020 - Mar 2021
# ...

# %%
df['Total_time']=df['Title'].apply(extraction_time)

# %%
df.head()
# Out:
#    Rank                                              Title  Score  Episodes  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#             Total_time
# 0  Apr 2009 - Jul 2010
# 1  Apr 2011 - Sep 2011
# 2  Oct 2022 - Dec 2022
# 3  Apr 2015 - Mar 2016
# 4  Apr 2019 - Jul 2019

# %%
from dateutil.relativedelta import relativedelta
from datetime import datetime

def calculate_total_months(period):
    try:
        start_str, end_str = period.split(' - ')
        start_date = datetime.strptime(start_str, '%b %Y')
        end_date = datetime.strptime(end_str, '%b %Y')
        r = relativedelta(end_date, start_date)
        return r.years * 12 + r.months + 1  # +1 to include the starting month
    except:
        return None
    

    # apply function

df['Months']=df['Total_time'].apply(calculate_total_months)

# %%
df
# Out:
#     Rank                                              Title  Score  Episodes  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04       148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03         2
# ...

# %% [markdown]
# which anime has the highest score

# %%
df[df['Score']==df['Score'].max()]['Title']
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# Name: Title, dtype: object

# %%
df[df['Score']==df['Score'].min()]["Title"]
# Out:
# 48    Mob Psycho 100 IIITV (12 eps)Oct 2022 - Dec 20...
# 49    Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# Name: Title, dtype: object

# %% [markdown]
# give me top 5 highest score

# %%
df['Title'].head()
# Out:
# 0    Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# 1    Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...
# 2    Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...
# 3    Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...
# 4    Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...
# Name: Title, dtype: object

# %% [markdown]
# whic anime has the highest episode count

# %%
df[df['Episodes']==df['Episodes'].max()]
# Out:
#     Rank                                              Title  Score  Episodes  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94       201
#
#              Total_time  Months
# 15  Apr 2006 - Mar 2010      48

# %% [markdown]
# animes with top 5 episode count

# %%
top5= df['Episodes'].sort_values(ascending=False).head(5)

# %%
print(top5)
# Out:
# 15    201
# 7     148
# 11    110
# 42     75
# 24     74
# Name: Episodes, dtype: int64

# %% [markdown]
# whic is the longest running anime

# %%
df[df['Months']==df['Months'].max()]
# Out:
#     Rank                                              Title  Score  Episodes  \
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02       110
#
#              Total_time  Months
# 11  Jan 1988 - Mar 1997     111

# %%
df
# Out:
#     Rank                                              Title  Score  Episodes  \
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04        51
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04         1
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04       148
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04        13
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03        13
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03         2
# ...

# %% [markdown]
# ## project 2: data capstone project

# %%
df1=pd.read_csv('Countries.csv')
df1
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
df1.shape
# Out:
# (194, 64)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %% [markdown]
# which country has the highest population

# %%
df1[df1['population']==df1['population'].max()]['country']
# Out:
# 75    India
# Name: country, dtype: object

# %% [markdown]
# what is the capital of the country with highest popul\tion

# %%
df1[df1['population']==df1['population'].max()]['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %% [markdown]
# which country has the least population

# %%
df1[df1['population']==df1['population'].min()]['country']
# Out:
# 179    Tuvalu
# Name: country, dtype: object

# %% [markdown]
# what is the capital of the country with least population

# %%
df1[df1['population']==df1['population'].min()]['capital_city']
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %% [markdown]
# give me top5 countries with highest democratic score

# %%
df1.sort_values(by='democracy_score',ascending=False,inplace=True)

# %%
df1.head()
# Out:
#          country         country_long            currency capital_city  \
# 127       Norway    Kingdom of Norway     Norwegian krone         Oslo
# 74       Iceland  Republic of Iceland       Iceland krona    Reykjavík
# 164       Sweden    Kingdom of Sweden       Swedish krona    Stockholm
# 122  New Zealand          New Zealand  New Zealand dollar   Wellington
# 46       Denmark   Kingdom of Denmark        Danish krone   Copenhagen
#
#                         region continent        demonym  latitude  longitude  \
# 127            Northern Europe    Europe      Norwegian      62.0       10.0
# 74             Northern Europe    Europe      Icelander      65.0      -18.0
# 164            Northern Europe    Europe        Swedish      62.0       15.0
# 122  Australia and New Zealand   Oceania  New Zealander     -41.0      174.0
# 46             Northern Europe    Europe         Danish      56.0       10.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
df1['country'].head()
# Out:
# 127         Norway
# 74         Iceland
# 164         Sweden
# 122    New Zealand
# 46         Denmark
# Name: country, dtype: object

# %% [markdown]
# how many total regions are there

# %%
df1['region'].value_counts().count()
# Out:
# np.int64(22)

# %% [markdown]
# how many countris lies in eastern europ region

# %%
df1['region'].value_counts()['Eastern Europe']
# Out:
# np.int64(10)

# %%
df1[df1['region']=="Eastern Europe"]['country']
# Out:
# 43      Czech Republic
# 151    Slovak Republic
# 24            Bulgaria
# 136             Poland
# 73             Hungary
# 139            Romania
# 111            Moldova
# 181            Ukraine
# 14             Belarus
# 140             Russia
# Name: country, dtype: object

# %% [markdown]
# who is the poltical  loeader of the 2nd largest highest populated country

# %%
df1[df1['population']==df1['population'].nlargest(2).iloc[1]]['political_leader']
# Out:
# 34    Xi Jinping
# Name: political_leader, dtype: object

# %% [markdown]
# how many countries are there whoes political leader are unknown

# %%
df1[df1['political_leader'].isna()]['country'].count()
# Out:
# np.int64(7)

# %% [markdown]
# how many countries have Republic in their full name

# %%
count=0
def counting(txt):
    global count
    if 'republic' in txt.lower():
        count+=1
    return txt
df['country_long']=df1['country_long'].apply(counting)
print(count)
# Out:
# 125

# %% [markdown]
# which country in african region has highest population

# %%
africa_df=df1[df1['continent']=='Africa']

# %%
africa_df[africa_df['population']==africa_df['population'].max()]['country']
# Out:
# 125    Nigeria
# Name: country, dtype: object
