# %% [markdown]
# # ANN - Implementation with TensorFlow/Keras

# %%
import tensorflow as tf
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import  StandardScaler

# %%
# load dataset
data=load_wine()
x=data.data
y=data.target
# train-test split
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42
)
# normalize the data
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)
print("training shape:",x_train.shape)
# Out:
# training shape: (142, 13)

# %%
# now build  ANN model
model=tf.keras.Sequential([
    tf.keras.layers.Dense(16,activation='relu',input_shape=(x_train.shape[1],)),
    tf.keras.layers.Dense(8,activation='relu'),
    tf.keras.layers.Dense(3,activation='softmax')
])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            27 │
# ...

# %%
# compile model
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# Train ANN
model.fit(x_train,y_train,epochs=20,verbose=1)
# Out:
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - accuracy: 0.3239 - loss: 1.0613
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3521 - loss: 1.0076
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3521 - loss: 0.9696
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3803 - loss: 0.9334
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4014 - loss: 0.9030
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4225 - loss: 0.8761
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4577 - loss: 0.8502
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4789 - loss: 0.8265
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4859 - loss: 0.8002
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5211 - loss: 0.7769
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5282 - loss: 0.7540
# Epoch 12/20
# ...

# %%
# Evaluate model
loss,accuracy=model.evaluate(x_test,y_test,verbose=0)
print("test loss:",loss)
print("test accuracy:",accuracy)
# Out:
# test loss: 0.5097265243530273
# test accuracy: 0.8333333134651184

# %% [markdown]
# # ----------------------------------------------------------------------------------
# # model = tf.keras.Sequential([
# #     tf.keras.layers.Dense(16, activation='relu', input_shape=(x_train.shape[1],)),
# #     tf.keras.layers.Dense(8, activation='relu'),
# #     tf.keras.layers.Dense(3, activation='softmax')
# # ])
# # ----------------------------------------------------------------------------------
# # EXPLANATION: Yahan TensorFlow Keras ka istemal karke ek Sequential (layer-by-layer) ANN model banaya ja raha hai:
# # - tf.keras.layers.Dense(16...): Pehli Hidden Layer hai jisme 16 neurons hain. Isme 'relu' activation function use hua hai jo negative values ko 0 kar deta hai.
# # - input_shape=(x_train.shape[1],): Yeh model ko bata raha hai ke input me kitne features (columns) aa rahe hain.
# # - tf.keras.layers.Dense(8...): Doosri Hidden Layer hai jisme 8 neurons hain aur iska activation bhi 'relu' hai.
# # - tf.keras.layers.Dense(3, activation='softmax'): Yeh Output Layer hai. Isme 3 neurons hain kyonke hamare paas wine ki 3 classes hain. 'softmax' activation function lagaya gaya hai taake jawab probability (percentages) me aaye jinka sum 1.0 ho.
#
#
# # ----------------------------------------------------------------------------------
# # model.summary()
# # ----------------------------------------------------------------------------------
# # EXPLANATION: Yeh command model ka poora huliya (structure) screen par print kar deti hai, jisme har layer ke neurons aur total seekhne wale parameters (Weights aur Biases) ki ginti saaf dikh jati hai.
#
#
# # ----------------------------------------------------------------------------------
# # # compile model
# # model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# # ----------------------------------------------------------------------------------
# # EXPLANATION: Training se pehle model ko configure (tayyar) kiya ja raha hai:
# # - optimizer='adam': Yeh model ke weights ko har step par update karne ka kaam karta hai (sabse best aur standard optimizer hai).
# # - loss='sparse_categorical_crossentropy': Jab hamare paas multiclass classification ho (0, 1, 2 labels) aur data integers me ho, toh yeh loss function use hota hai jo ghalat jawab par model ko punish karta hai.
# # - metrics=['accuracy']: Isse hum model ki sahi jawab dene ki percentage track karte hain.
#
#
# # ----------------------------------------------------------------------------------
# # # Train ANN
# # model.fit(x_train, y_train, epochs=20, verbose=1)
# # ----------------------------------------------------------------------------------
# # EXPLANATION: Yahan asli parhai (training) shuru ho rahi hai:
# # - model.fit: Model ko x_train (features) aur y_train (asli answers) diye ja rahe hain.
# # - epochs=20: Model poore data ko 20 martaba suru se aakhir tak parhega aur seekhega.
# # - verbose=1: Iska matlab hai ke screen par har epoch ki progress bar, loss aur accuracy live dikhayi degi.
#
#
# # ----------------------------------------------------------------------------------
# # # Evaluate model
# # loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
# # print("test loss:", loss)
# # print("test accuracy:", accuracy)
# # ----------------------------------------------------------------------------------
# # EXPLANATION: Parhai khatam hone ke baad ab model ka real test ho raha hai:
# # - model.evaluate: Model ko woh 20% anjan data (x_test, y_test) diya gaya jo usne training me kabhi nahi dekha tha.
# # - verbose=0: Screen par koi faltu progress bar nahi dikhegi, chupke se evaluation ho jayegi.
# # - print(...): Test data par model ka kitna loss aaya aur kitni final accuracy aayi, use screen par display kar diya.
#
#
# # ----------------------------------------------------------------------------------
# # # now build ANN model ... model.summary() (Repeated Block)
# # ----------------------------------------------------------------------------------
# # EXPLANATION: Code ke aakhir me aapne wahi upar wala Sequential model dobara likha hai
# # aur summary call ki hai. Yeh purane model ko reset kar ke bilkul naya khali model
#
# **bold text** **bold text**
